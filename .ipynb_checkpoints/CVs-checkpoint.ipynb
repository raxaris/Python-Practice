# %% [markdown]
# # Packs installation

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: numpy>=1.20 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\raxar\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Output of first 20 rows of data frame

# %%
df = pd.read_csv("CV.csv")

# %%
df.head(20)
# Out:
#                            Title            Specialization   Salary  Age  \
# 0               Программист Java  Программист, разработчик    40000   38
# 1                 Java Developer  Программист, разработчик   400000   22
# 2                Java Developer   Программист, разработчик   500000   22
# 3                 Java Developer  Программист, разработчик    60000   20
# 4                 Java developer  Программист, разработчик   500000   20
# 5               Java-программист  Программист, разработчик     4000   28
# 6                 Java-developer  Программист, разработчик    70000   24
# 7          Middle Java developer  Программист, разработчик   500000   22
# 8                 Java Developer  Программист, разработчик   150000   23
# 9               Java-разработчик  Программист, разработчик   300000   28
# 10              Программист Java  Программист, разработчик      500   40
# 11              Java-разработчик  Программист, разработчик   100000   20
# 12                Java Developer  Программист, разработчик  1200000   33
# 13              Программист Java  Программист, разработчик   800000   28
# 14              Java-разработчик  Программист, разработчик  1200000   35
# 15              Java-разработчик  Программист, разработчик   100000   29
# 16          FullStack (Java, JS)  Программист, разработчик     3000   30
# 17      Software java developer   Программист, разработчик   700000   25
# 18  программист разработчик Java  Программист, разработчик  1000000   43
# 19         Senior Java Developer  Программист, разработчик     5000   37
#
#         Sex
# 0   Мужчина
# 1   Мужчина
# 2   Мужчина
# 3   Мужчина
# 4   Мужчина
# 5   Мужчина
# 6   Мужчина
# 7   Мужчина
# 8   Мужчина
# 9   Мужчина
# 10  Мужчина
# 11  Мужчина
# 12  Мужчина
# 13  Мужчина
# 14  Мужчина
# 15  Мужчина
# 16  Мужчина
# 17  Мужчина
# 18  Мужчина
# 19  Мужчина

# %% [markdown]
# # Sorting datagrame  by the salary, age and title

# %%
df = df.sort_values(by=['Salary', 'Age', 'Title'], ascending=[False, True, True])
df
# Out:
#                            Title            Specialization   Salary  Age  \
# 12                Java Developer  Программист, разработчик  1200000   33
# 32                Java Developer  Программист, разработчик  1200000   33
# 14              Java-разработчик  Программист, разработчик  1200000   35
# 34              Java-разработчик  Программист, разработчик  1200000   35
# 18  программист разработчик Java  Программист, разработчик  1000000   43
# 38  программист разработчик Java  Программист, разработчик  1000000   43
# 13              Программист Java  Программист, разработчик   800000   28
# 33              Программист Java  Программист, разработчик   800000   28
# 17      Software java developer   Программист, разработчик   700000   25
# 37      Software java developer   Программист, разработчик   700000   25
# 4                 Java developer  Программист, разработчик   500000   20
# 24                Java developer  Программист, разработчик   500000   20
# 3                Java Developer   Программист, разработчик   500000   22
# 23               Java Developer   Программист, разработчик   500000   22
# 7          Middle Java developer  Программист, разработчик   500000   22
# 27         Middle Java developer  Программист, разработчик   500000   22
# 1                 Java Developer  Программист, разработчик   400000   22
# 21                Java Developer  Программист, разработчик   400000   22
# 9               Java-разработчик  Программист, разработчик   300000   28
# 29              Java-разработчик  Программист, разработчик   300000   28
# 8                 Java Developer  Программист, разработчик   150000   23
# 28                Java Developer  Программист, разработчик   150000   23
# 11              Java-разработчик  Программист, разработчик   100000   20
# 31              Java-разработчик  Программист, разработчик   100000   20
# 15              Java-разработчик  Программист, разработчик   100000   29
# 35              Java-разработчик  Программист, разработчик   100000   29
# 6                 Java-developer  Программист, разработчик    70000   24
# 26                Java-developer  Программист, разработчик    70000   24
# 2                 Java Developer  Программист, разработчик    60000   20
# 22                Java Developer  Программист, разработчик    60000   20
# 0               Программист Java  Программист, разработчик    40000   38
# 20              Программист Java  Программист, разработчик    40000   38
# 19         Senior Java Developer  Программист, разработчик     5000   37
# 39         Senior Java Developer  Программист, разработчик     5000   37
# 5               Java-программист  Программист, разработчик     4000   28
# 25              Java-программист  Программист, разработчик     4000   28
# 16          FullStack (Java, JS)  Программист, разработчик     3000   30
# 36          FullStack (Java, JS)  Программист, разработчик     3000   30
# 10              Программист Java  Программист, разработчик      500   40
# 30              Программист Java  Программист, разработчик      500   40
#
#         Sex
# 12  Мужчина
# 32  Мужчина
# 14  Мужчина
# 34  Мужчина
# 18  Мужчина
# 38  Мужчина
# 13  Мужчина
# 33  Мужчина
# 17  Мужчина
# 37  Мужчина
# 4   Мужчина
# 24  Мужчина
# 3   Мужчина
# 23  Мужчина
# 7   Мужчина
# 27  Мужчина
# 1   Мужчина
# 21  Мужчина
# 9   Мужчина
# 29  Мужчина
# 8   Мужчина
# 28  Мужчина
# 11  Мужчина
# 31  Мужчина
# 15  Мужчина
# 35  Мужчина
# 6   Мужчина
# 26  Мужчина
# 2   Мужчина
# 22  Мужчина
# 0   Мужчина
# 20  Мужчина
# 19  Мужчина
# 39  Мужчина
# 5   Мужчина
# 25  Мужчина
# 16  Мужчина
# 36  Мужчина
# 10  Мужчина
# 30  Мужчина

# %% [markdown]
# # Calculating minimum, maximum and mean average of the salary of all

# %%
salary_min = df['Salary'].min()
salary_max = df['Salary'].max()
salary_mean = df['Salary'].mean()

print("Minimum salary: ${:,.2f}".format(salary_min))
print("Maximum salary: ${:,.2f}".format(salary_max))
print("Mean salary: ${:,.2f}".format(salary_mean))
# Out:
# Minimum salary: $500.00
# Maximum salary: $1,200,000.00
# Mean salary: $381,625.00

# %% [markdown]
# #  Calculating minimum, maximum and mean average of the salary of each sex, specialization and citizenship

# %%
grouped_df = df.groupby(['Sex', 'Specialization'])
result = grouped_df.agg({'Salary': ['min', 'max', 'mean']})

result
# Out:
#                                  Salary
#                                     min      max      mean
# Sex     Specialization
# Мужчина Программист, разработчик    500  1200000  381625.0

# %% [markdown]
# # Graphs

# %% [markdown]
# ## Chart of the average mean of expected salary each country’s citizenship or of each sex

# %%
grouped_df = df.groupby(['Sex'])['Salary'].mean()

grouped_df.plot(kind='bar')

plt.title('Mean Average of Expected Salary by Sex')
plt.xlabel('Sex')
plt.ylabel('Mean Expected Salary')

plt.show()

# %% [markdown]
# ## Chart of the minimum, maximum, and mean average of the salary of all

# %%
min_salary = df['Salary'].min()
max_salary = df['Salary'].max()
mean_salary = df['Salary'].mean()

plt.bar(['Minimum', 'Maximum', 'Mean Average'], [min_salary, max_salary, mean_salary])

plt.title('Minimum, Maximum, and Mean Average of Salary')
plt.xlabel('Statistics')
plt.ylabel('Salary')

plt.show()

# %% [markdown]
# ##  Chart of minimum, maximum and mean average of the salary of all each specialization

# %%
grouped_df = df.groupby(['Specialization'])['Salary'].agg(['min', 'max', 'mean'])

grouped_df.plot(kind='bar')

plt.title('Minimum, Maximum, and Mean Average of Salary by Specialization')
plt.xlabel('Specialization')
plt.ylabel('Salary')

plt.show()

# %% [markdown]
# ## Chart of minimum, maximum and mean average of ages

# %%
min_age = df['Age'].min()
max_age = df['Age'].max()
mean_age = df['Age'].mean()


plt.boxplot(df['Age'])

plt.plot([1, 1], [min_age, min_age], 'go', markersize=10)
plt.plot([1, 1], [max_age, max_age], 'ro', markersize=10)
plt.plot([1, 1], [mean_age, mean_age], 'bo', markersize=10)

plt.title('Minimum, Maximum, and Mean Average of Age')
plt.xticks([1], ['Age'])
plt.ylabel('Age')

plt.show()

# %% [markdown]
# ## Graph of minimum, maximum and mean average title

# %%
salary_stats = df.groupby('Title')['Salary'].agg(['min', 'max', 'mean'])

title_counts = df['Title'].value_counts()

fig, ax = plt.subplots()
ax.bar(title_counts.index, salary_stats['mean'], yerr=[
       salary_stats['mean'] - salary_stats['min'], salary_stats['max'] - salary_stats['mean']])
ax.set_xticks(range(len(title_counts.index)))
ax.set_xticklabels(title_counts.index, rotation=90)
ax.set_ylabel('Salary')
ax.set_title('Minimum, Maximum, and Mean Average of Salary for Each Title')

plt.show()
